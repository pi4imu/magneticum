# %%
#%matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  
# %matplotlib inline

#!ls

# %% [markdown]
# AGN

# %%
data_name = "../eROSITA_cluster_agn_box2hr/agn_143.dat"
headers1 = ["ID", "x [kpc/h]", "y [kpc/h]", "z[kpc/h]", "M [Msol]", "Mdot [Msol/year]", "Lbol [erg/s]", "Lsoftx [erg/s]", "Lhard [erg/s]", "f_obs"]
table1 = pd.read_csv(data_name, comment='#', header=None, sep='\s+', names=headers1)#, names=headers)
table1
# Out:
#             ID  x [kpc/h]  y [kpc/h]   z[kpc/h]     M [Msol]  \
# 0            0  215179.11  218411.78  344891.88  107401000.0
# 1            1  214912.95  215929.02  344847.69  101458000.0
# 2            2  214616.41  217050.30  344982.41  465890000.0
# 3            3  218085.66  213646.33  341205.22   95105600.0
# 4            4  213876.98  213007.59  345791.06  127957000.0
# ...        ...        ...        ...        ...          ...
# 415234  451955  201749.25  198487.03  334783.69   90533400.0
# 415235  451956  203433.55  201076.81  335115.09   61086100.0
# 415236  451957  200335.25  199029.84  334426.22  590928000.0
# 415237  451958  200368.23  199123.00  334492.62  123843000.0
# 415238  451959  200697.66  199155.36  334743.72   49779600.0
#
#         Mdot [Msol/year]  Lbol [erg/s]  Lsoftx [erg/s]  Lhard [erg/s]  \
# 0               0.000669  4.220288e+42    3.035406e+41   4.480896e+41
# 1               0.000020  1.251598e+41    1.141467e+40   1.807877e+40
# ...

# %%
plt.rcParams["figure.figsize"] = [14.00, 7.00]
#plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

data_table = table1.to_numpy().astype(float)

x = data_table[:,1]
y = data_table[:,2]
z = data_table[:,3]
c = data_table[:,9]

#ax.set_xlabel('X Label')
#ax.set_ylabel('Y Label')
#ax.set_zlabel('Z Label')

img = ax.scatter(x, y, z, c=c, cmap=plt.hot())
fig.colorbar(img)
plt.show()

# %% [markdown]
# CLUSTER

# %%
data_name = "eROSITA_cluster_agn_box2hr/cluster_143.dat"
headers2 = ["ID",
            "x [kpc/h]", 
            "y [kpc/h]",
            "z[kpc/h]",
            "Mvir [Msol/h]", 
            "M200m [Msol/h]",
            "M500m [Msol/h]", 
            "M200c [Msol/h]", 
            "M500c [Msol/h]", 
            "R500c [kpc/h]",
            "Mgas_500c [Msol/h]",  
            "Mstar_500c [msol/h]", 
            "T_500c [keV]",
            "Lx_500c [1e44 erg/s]"]
  
table2 = pd.read_csv(data_name, comment='#', sep='\s+', header=None, names=headers2)
table2
# Out:
#        ID   x [kpc/h]   y [kpc/h]    z[kpc/h]  Mvir [Msol/h]  M200m [Msol/h]  \
# 0       0  208645.730  203875.190  349623.060   1.807310e+15    2.416030e+15
# 1       1  314142.500   24298.051  277934.940   1.189800e+15    1.390380e+15
# 2       2  183986.140  193501.810  332643.380   6.955270e+14    9.042830e+14
# 3       3   83780.227  206433.700  144859.940   1.193790e+15    1.261390e+15
# 4       4  327387.310  233389.410  209370.670   1.027230e+15    1.213170e+15
# ..    ...         ...         ...         ...            ...             ...
# 817  1282  195206.560  145802.700  281719.250   8.474640e+13    9.693490e+13
# 818  1317   27537.789  159545.860   61034.664   8.134000e+13    8.691250e+13
# 819  1339  112005.720  227611.670   74467.383   7.942170e+13    8.445550e+13
# 820  1346  214400.500  222135.730   51173.164   7.875100e+13    8.424510e+13
# 821  1398  213697.380  248975.190  105530.090   7.599380e+13    8.405380e+13
#
# ...

# %%
plt.rcParams["figure.figsize"] = [14.00, 7.00]
#plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

data_table = table2.to_numpy().astype(float)

x = data_table[:,1]
y = data_table[:,2]
z = data_table[:,3]
c = data_table[:,12]

img = ax.scatter(x, y, z, c=c, cmap=plt.hot())
fig.colorbar(img)
plt.show()
