# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.cosmology import FlatLambdaCDM

import os

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm, colors

import mpl_toolkits.mplot3d.art3d as art3d
from matplotlib.patches import Circle

import xspec as x

# %% [markdown]
# #### For eROSITA 30.0x30.0 field we take all clusters within the lightcone (flag=0) with $M_{500}> 10^{14} M_{\odot}$:

# %%
clusters = pd.read_csv("../data/eROSITA_30.0x30.0/Catalouges/cluster.dat", sep='\s+', header=0)
clusters = clusters[clusters["M500"]>1e14]
clusters = clusters[clusters["flag"]==0]
clusters
# Out:
#        ihal     x_pix     y_pix     z_pix      Rrel          Mvir    z_true  \
# 171     110  0.970969  0.479718  0.014316  0.004703  2.432930e+14  0.157249
# 187     163  0.388924  0.570999  0.016006  0.004675  2.390080e+14  0.157312
# 350      77  0.380183  0.570491  0.033800  0.005197  3.282700e+14  0.157977
# 820      68  0.735543  0.863489  0.086085  0.005228  3.341870e+14  0.159935
# 1245    111  0.804864  0.355207  0.133510  0.004668  2.379170e+14  0.161713
# ...     ...       ...       ...       ...       ...           ...       ...
# 18589   113  0.839159  0.495644  0.394607  0.011199  2.242680e+14  0.063945
# 18610   199  0.149218  0.307198  0.406194  0.011455  2.400200e+14  0.064342
# 19523   349  0.373303  0.943536  0.987909  0.010375  1.783400e+14  0.084342
# 19771   323  0.759637  0.387809  0.508332  0.020783  1.912580e+14  0.034099
# 19787    83  0.926032  0.822913  0.526959  0.026050  3.766600e+14  0.034717
#
#           z_obs          M500     R500      Mstar500       Mgas500     T500  \
# 171    0.157891  1.366960e+14  688.128  4.470500e+12  1.209540e+13  2.44633
# 187    0.159659  1.126680e+14  645.187  2.896080e+12  1.061830e+13  2.43074
# 350    0.157810  1.925340e+14  771.351  5.156740e+12  2.121000e+13  3.21771
# 820    0.160192  1.800240e+14  754.271  6.340420e+12  1.596800e+13  3.57076
# 1245   0.161111  1.321030e+14  680.349  4.667490e+12  9.869480e+12  2.78095
# ...         ...           ...      ...           ...           ...      ...
# 18589  0.063977  1.184480e+14  615.838  2.883010e+12  1.160680e+13  2.22808
# 18610  0.064928  1.282700e+14  632.408  3.427130e+12  1.130680e+13  2.26553
# 19523  0.084015  1.055570e+14  592.650  3.313370e+12  6.942770e+12  2.39539
# 19771  0.033707  1.272360e+14  616.706  3.593030e+12  1.067760e+13  2.61661
# 19787  0.033992  1.682650e+14  676.952  5.699780e+12  1.686950e+13  2.84568
#
#           Lx500    Ysz500          M200      R200  flag
# 171    0.707698  0.000003  2.049620e+14  1068.920     0
# 187    0.532571  0.000003  2.049290e+14  1068.880     0
# 350    1.515690  0.000005  2.887220e+14  1198.270     0
# 820    0.972861  0.000004  2.724390e+14  1175.290     0
# 1245   0.452088  0.000003  1.944720e+14  1050.360     0
# ...         ...       ...           ...       ...   ...
# 18589  0.537683  0.000002  1.889120e+14   976.536     0
# 18610  0.455429  0.000002  1.935300e+14   984.440     0
# 19523  0.231120  0.000002  1.464050e+14   897.005     0
# 19771  0.651073  0.000003  1.638830e+14   910.698     0
# 19787  0.951228  0.000004  2.866160e+14  1097.250     0
#
# [84 rows x 18 columns]

# %% [markdown]
# ihal: HaloID
#
# x_pix,y_pix: position of the cluster in the Lightcone [0..1]. Multiply by 30
#              degree to get position in sky.
#
# z_pix:       relative position within the slice [0..1]
#
# Note on x_pix,y_pix,z_pix: Objects are included if their size overlaps with the
#                            Lightcone, therefore these central positions can be
#                            slightly outside the Lightcone. The value of flag
#                            (last column) indicates if a object is fully within
#                            the Lightcone (0) or if it is only partially within
#                            the Lightcone (1).
#
# Rrel:        relative size of the virial radius (TopHat). Multiply by 30 degree
#              to obtain the size of the virial radius on the sky.
#
# Mvir         Nvir (TopHat) in Msol/h
#
# z_true:      real redshift of the object (use this for distances)
#
# z_obs:       redshift as spectroscopicly observed (use this as observed redshift)
#
# M500:        M500 (critical) in Msol/h
#
# R500:        R500 (critical) in kpc/h
#
# Mstar500:    Stellar mass within R500 (critical) in Msol/h
#
# Mgas500:     Gas mass within R500 (critical) in Msol/h
#
# T500:        Mass weighted temperature within R500 (critical) in keV
#
# Lx500:       Bolometric X-Ray luminosity within R500 (critical) in 1e44 erg/s
#
# Ysz500:      ComptonY within R500 (critical)
#
# M200:        M200 (critical) in Msol/h
#
# R200         R200 (critical) in kpc/h
#
# flag:        Indication if object is fully (=0) or only partial (=1) within the
#              Lightcone.

# %%
len(clusters), min(clusters["z_true"]), max(clusters["z_true"])
# Out:
# (84, 0.034098784, 0.19434476)

# %% [markdown]
# #### ZuHone's figure 1:

# %%
plt.figure(figsize = (7,3.5))

plt.subplot(121)
plt.hist(clusters["M500"]/10**14, bins=30, histtype='stepfilled')
plt.xlabel("$M_{500}$ in units of $10^{14} M_{\odot} h^{-1}$")

plt.subplot(122)
plt.hist(clusters["z_true"], bins=30, histtype='stepfilled')
plt.xlabel("Redshift $z_{true}$")

plt.show()


plt.figure(figsize = (5,5))

plt.scatter(clusters["z_true"], clusters["M500"]/10**14)
plt.xlabel("Redshift $z_{true}$")
plt.ylabel("$M_{500}$ in units of $10^{14} M_{\odot} h^{-1}$")

plt.show()

# %% [markdown]
# The redshift used in computing distances $z_{true}$ is obtained by computing the offset of the cluster center from the center of the slice, and the redshift used in fitting spectra $z_{obs}$ also takes into account the peculiar velocity of the cluster within the slice.

# %% [markdown]
# #### Plotting all these clusters in 2D:

# %%
x_c = 30*clusters["x_pix"].values    # deg
y_c = 30*clusters["y_pix"].values    # deg
#z_c = clusters["z_pix"]              # relative position within the slice [0...1]
z_c = clusters["z_true"]

r_500 = clusters["R500"].values        # kpc/h
redshifts = clusters["z_true"].values

h = 0.704
Omega_M = 0.272
D_A = FlatLambdaCDM(H0=100*h, Om0=Omega_M).angular_diameter_distance(redshifts) # Mpc

r_500_rescaled = [num/denom*180/np.pi for num, denom in zip(r_500*h, 1000*D_A.value)]  # degrees

R_vir = 30*clusters["Rrel"].values

# %% [markdown]
# #### Example from `run_phox_cluster_erosita_lightcone.cmd` as motivator to take Rrel*30 as $R_{500}$:

# %%
clusters.iloc[28]["x_pix"]*30-5, clusters.iloc[28]["y_pix"]*30-5, clusters.iloc[28]["Rrel"]*30
# Out:
# (17.6464642, 18.0108214, 0.190842306)

# %% [markdown]
# #### Please note that $R_{rel}$ (virial radius) is taken as $R_{500}$, which may be bad decision!

# %%
plt.figure(figsize=(6,5))#, layout='constrained')

plt.scatter(x_c, y_c, c=redshifts, cmap='viridis', s=2)

for xc, yc, r in zip(x_c, y_c, R_vir):
    plt.gca().add_patch( plt.Circle( (xc, yc), r, fill = False) )
    
plt.gca().invert_xaxis()
    
plt.colorbar(label="Redshift $z_{true}$")

plt.xlabel("R.A., deg")
plt.ylabel("DEC, deg")

plt.show()

# %% [markdown]
# #### Adding slices from Phox and drawing in 3D:

# %%
wd = "../data/eROSITA_30.0x30.0/Phox/"
mylist = sorted(os.listdir(wd))

phlists = [item for item in mylist if item[:6] == "phlist"]

print(phlists)

phlists_redshifts = [fits.open(wd+item)[0].header["REDSHIFT"] for item in phlists]#[::-1]

print(phlists_redshifts)
# Out:
# ['phlist_124.fits', 'phlist_128.fits', 'phlist_132.fits', 'phlist_136.fits', 'phlist_140.fits']
# [0.174192889973847, 0.13708140389145, 0.101142861718869, 0.0663401914452304, 0.032637492755919]

# %% [markdown]
# #### ...considering `geometry.dat`...

# %%
geometry = pd.read_csv("../data/eROSITA_30.0x30.0/Catalouges/geometry.dat", sep='\s+', header=2)
geometry
# Out:
#    snapNr      ztab    zslice   z_start     z_end          x0          y0  \
# 0     144  0.001001  0.008625  0.000000  0.017281  230.604600   52.929941
# 1     140  0.033671  0.033822  0.017281  0.050478  305.341400  149.855590
# 2     136  0.067408  0.067555  0.050478  0.084760   97.871486  134.586170
# 3     132  0.102245  0.102388  0.084760  0.120158  185.353850  229.067940
# 4     128  0.138220  0.138357  0.120158  0.156713  146.337120  179.784950
# 5     124  0.175368  0.175501  0.156713  0.194460  170.716390  187.570430
#
#            z0       depth       width
# 0   38.137176   73.327162   21.167728
# 1  172.109480  139.387980   82.573299
# 2  117.805860  141.855220  163.761220
# 3  294.134880  144.222380  246.344710
# 4  264.241690  146.478010  330.262680
# 5  175.891600  148.610980  415.447530

# %% [markdown]
# #### (there are no clusters of interest in snap number 144)
#
# snapNr:   Snap Number
#
# ztab:     redshift of the simulation output used for the slice
#
# zslice:   mean redshift of the slice (e.g. redshift corresponding to the mean popper distance of the slice)
#
# z_start:  minimum redshift of the slice
#
# z_end:    maximum redshift of the slice
#
# x0,y0,z0: Center position of the box used
#
# depth:    proper distance in z direction of the slice in Mpc
#
# width:    proper distance of the field of view in Mpc

# %%
fig = plt.figure(figsize=(10,8), layout="constrained")

ax = fig.add_subplot(projection='3d')

ax.scatter(x_c, redshifts, zs=y_c, zdir='z', cmap='viridis')

for xc, yc, r, rdsh in zip(x_c, y_c, R_vir, redshifts):
    p = Circle( (xc, yc), r*5, fill = False)
    ax.add_patch(p)
    art3d.pathpatch_2d_to_3d(p, z=rdsh, zdir="y")

ax.set_xlabel("R.A., deg")
ax.set_ylabel('\n \n Redshift $z$')
ax.set_zlabel("DEC, deg")

ax.invert_xaxis()

xx, yy = np.meshgrid(range(30), range(30))
for rdsh in phlists_redshifts:
    ax.plot_surface(xx, rdsh, yy, alpha=0.2, color='red')
    
xx, yy = np.meshgrid(range(30), range(30))
for rdsh in geometry["z_end"]:
    ax.plot_surface(xx, rdsh, yy, alpha=0.2, color='green')

ax.view_init(elev=30., azim=-25)

ax.set_box_aspect(aspect = (1,3,1), zoom = 1)

ax.set_title("Note: $R_{500}$\'s are multiplied by 5")

plt.show()

# %% [markdown]
# #### Binning clusters between slices (keys = halo index (not ihal!), values = redshifts and snap ID's of slices):

# %%
#def choose_slice(zZz):
        
#    for i in range(0, len(phlists_redshifts)):
    
#        if zZz > phlists_redshifts[i]:
            
            #print(zZz, rlist[-(1+i)])
            
#            return phlists_redshifts[i], phlists[i][7:10]


binned_clusters = {}
    
for ind in clusters.index:
    
    cl = clusters.loc[ind]
    
    zxcvbn = cl["z_true"]
    
    #print(ind, zxcvbn)
    
    for i in range(0, len(phlists_redshifts)):
        
        #print(zxcvbn, phlists_redshifts[i])
    
        if zxcvbn > phlists_redshifts[i]:
            
            binned_clusters[ind] = phlists_redshifts[i], phlists[i][7:10]
            
            #print(zxcvbn, phlists_redshifts[i], binned_clusters[ind])
            
            break
                
binned_clusters
# Out:
# {171: (0.13708140389145, '128'),
#  187: (0.13708140389145, '128'),
#  350: (0.13708140389145, '128'),
#  820: (0.13708140389145, '128'),
#  1245: (0.13708140389145, '128'),
#  1380: (0.13708140389145, '128'),
#  1707: (0.13708140389145, '128'),
#  1819: (0.13708140389145, '128'),
#  1838: (0.13708140389145, '128'),
#  2270: (0.13708140389145, '128'),
#  2386: (0.13708140389145, '128'),
#  2421: (0.13708140389145, '128'),
#  2471: (0.13708140389145, '128'),
#  2593: (0.13708140389145, '128'),
#  2603: (0.13708140389145, '128'),
#  2815: (0.13708140389145, '128'),
#  2904: (0.13708140389145, '128'),
#  3155: (0.13708140389145, '128'),
#  3886: (0.13708140389145, '128'),
#  3985: (0.13708140389145, '128'),
#  4613: (0.174192889973847, '124'),
#  4967: (0.174192889973847, '124'),
#  5326: (0.174192889973847, '124'),
#  5443: (0.174192889973847, '124'),
#  6001: (0.174192889973847, '124'),
#  6496: (0.174192889973847, '124'),
#  6529: (0.174192889973847, '124'),
#  6582: (0.174192889973847, '124'),
#  6695: (0.174192889973847, '124'),
#  6740: (0.174192889973847, '124'),
#  7191: (0.174192889973847, '124'),
#  7308: (0.174192889973847, '124'),
#  7364: (0.174192889973847, '124'),
#  7409: (0.174192889973847, '124'),
#  7553: (0.174192889973847, '124'),
#  7996: (0.174192889973847, '124'),
#  8211: (0.174192889973847, '124'),
#  8930: (0.174192889973847, '124'),
#  9240: (0.101142861718869, '132'),
#  9389: (0.101142861718869, '132'),
#  9636: (0.101142861718869, '132'),
#  9836: (0.101142861718869, '132'),
#  10018: (0.101142861718869, '132'),
#  10548: (0.101142861718869, '132'),
#  10551: (0.101142861718869, '132'),
#  10820: (0.101142861718869, '132'),
#  10842: (0.101142861718869, '132'),
#  10928: (0.101142861718869, '132'),
#  11141: (0.101142861718869, '132'),
#  11272: (0.101142861718869, '132'),
#  11428: (0.101142861718869, '132'),
#  11468: (0.101142861718869, '132'),
#  11599: (0.101142861718869, '132'),
#  11847: (0.13708140389145, '128'),
#  12045: (0.13708140389145, '128'),
#  12296: (0.13708140389145, '128'),
#  13334: (0.13708140389145, '128'),
#  13675: (0.13708140389145, '128'),
#  13751: (0.13708140389145, '128'),
#  14038: (0.13708140389145, '128'),
#  14434: (0.13708140389145, '128'),
#  14559: (0.13708140389145, '128'),
#  14660: (0.0663401914452304, '136'),
#  14667: (0.0663401914452304, '136'),
#  14726: (0.0663401914452304, '136'),
#  14857: (0.0663401914452304, '136'),
#  14936: (0.0663401914452304, '136'),
#  15138: (0.0663401914452304, '136'),
#  16666: (0.101142861718869, '132'),
#  17017: (0.101142861718869, '132'),
#  17086: (0.101142861718869, '132'),
#  17174: (0.101142861718869, '132'),
#  17365: (0.101142861718869, '132'),
#  17415: (0.101142861718869, '132'),
#  17421: (0.101142861718869, '132'),
#  17638: (0.101142861718869, '132'),
#  17654: (0.101142861718869, '132'),
#  17964: (0.101142861718869, '132'),
#  18073: (0.032637492755919, '140'),
#  18589: (0.032637492755919, '140'),
#  18610: (0.032637492755919, '140'),
#  19523: (0.0663401914452304, '136'),
#  19771: (0.032637492755919, '140'),
#  19787: (0.032637492755919, '140')}

# %% [markdown]
# ### TODO:
#
# Maybe its better to invert dictionary.

# %% [markdown]
# #### Binning clusters and checking if they are binned correctly

# %%
BINS = phlists_redshifts[::-1] + [0.2]

print(BINS)

plt.figure(figsize=(4,4))      
        
plt.hist(clusters["z_true"], bins=BINS, histtype='stepfilled')
plt.xlabel("Redshift $z_{true}$")

check = np.unique([a[0] for a in binned_clusters.values()], return_counts=True)[1] # if binned correctly
    
plt.plot(phlists_redshifts, check[::-1], color = 'black')

for rdsh in phlists_redshifts:
    plt.axvline(rdsh, color='red')

plt.show()
# Out:
# [0.032637492755919, 0.0663401914452304, 0.101142861718869, 0.13708140389145, 0.174192889973847, 0.2]

# %% [markdown]
# #### Facts
#
# Programs distributed with HEASOFT are called “ftools”. If you want to know more about the parameters of an FTOOL, use the command fhelp ftoolname where “ftoolname” is the name of the FTOOL. To get a list of all available FTOOLS, use fhelp ftools.

# %% [markdown]
# `!fv ../data/eROSITA_30.0x30.0/Phox/phlist_140.fits`

# %% [markdown]
# `!fstruct ../data/eROSITA_30.0x30.0/Phox/phlist_140.fits`

# %% [markdown]
# #### Searching for photons from these clusters in photon lists. At first for one cluster.

# %% [markdown]
# Steps: (1) take each snap, (2) choose only clusters related to this snap, (3) for each cluster choose only photons inside $R_{500}$.

# %%
snap_id = '124'

related_clusters = [i for i,j in binned_clusters.items() if j[1] == snap_id]
related_clusters
# Out:
# [4613,
#  4967,
#  5326,
#  5443,
#  6001,
#  6496,
#  6529,
#  6582,
#  6695,
#  6740,
#  7191,
#  7308,
#  7364,
#  7409,
#  7553,
#  7996,
#  8211,
#  8930]

# %%
current_cluster_num = related_clusters[3]

current_cluster_num
# Out:
# 5443

# %%
current_cluster = clusters.loc[current_cluster_num]

current_cluster
# Out:
# ihal        2.220000e+02
# x_pix       9.428021e-01
# y_pix       5.505987e-01
# z_pix       5.997911e-01
# Rrel        4.331745e-03
# Mvir        1.901030e+14
# z_true      1.792698e-01
# z_obs       1.790772e-01
# M500        1.244820e+14
# R500        6.669860e+02
# Mstar500    3.475060e+12
# Mgas500     1.155390e+13
# T500        2.694580e+00
# Lx500       9.059070e-01
# Ysz500      3.091406e-06
# M200        1.609490e+14
# R200        9.861700e+02
# flag        0.000000e+00
# Name: 5443, dtype: float64

# %%
RA_c = current_cluster["x_pix"]*30-5
DEC_c = current_cluster["y_pix"]*30-5
R_vir = current_cluster["Rrel"]*30

R_500 = current_cluster["R500"]*0.704  # kpc
ztrue = current_cluster["z_true"]

D_A = FlatLambdaCDM(H0=100*0.704, Om0=0.272).angular_diameter_distance(ztrue)*1000 # kpc

R_500_rescaled = R_500/D_A.value*180/np.pi

RA_c, DEC_c, R_vir, R_500_rescaled
# Out:
# (23.2840633, 11.5179616, 0.129952347, 0.0432004641787449)

# %%
hdul = fits.open("../data/eROSITA_30.0x30.0/Phox/phlist_"+snap_id+".fits")

SLICE = pd.DataFrame(hdul[2].data[:])

display(SLICE)

hdul.close()
# Out:
#            ENERGY        RA        DEC
# 0        0.131364  7.053424   5.213879
# 1        0.133200  7.053719   5.213956
# 2        0.144594  7.053277   5.213721
# 3        0.150129  7.053310   5.213861
# 4        0.172124  7.054762   5.215268
# ...           ...       ...        ...
# 4876383  1.381983  2.412350  17.831232
# 4876384  0.874915  2.212069  17.840137
# 4876385  4.085876  2.213109  17.836908
# 4876386  1.530260  1.634259  14.999208
# 4876387  0.327976  2.413611  17.826101
#
# [4876388 rows x 3 columns]

# %%
from astropy.table import Table

# %%
def extract_photons(ra_cl, dec_cl, R_cl, snapID):
    
    t = Table.read("../data/eROSITA_30.0x30.0/Phox/phlist_"+snapID+".fits", hdu=2)
    
    SLICE = t.to_pandas()
    
    SLICE["check"]=np.where((SLICE["RA"]-ra_cl)**2+(SLICE["DEC"]-dec_cl)**2 <= R_cl**2, True, False)
    
    #display(SLICE)

    #if (ra_ph-x_cl)**2 + (dec_ph-y_cl)**2 <= r_cl**2:
     
    df = SLICE[SLICE['check'] == True]
    
    display(df)
    
    #df = df.drop("RA", axis=1)
    #df = df.drop("DEC", axis=1)
    
    return df.drop("check", axis=1)

    
dddfff = extract_photons(RA_c, DEC_c, R_vir, snap_id)

display(dddfff)
# Out:
#            ENERGY         RA        DEC  check
# 201051   0.250424  23.293491  11.519407   True
# 201114   0.165772  23.263769  11.536244   True
# 201191   0.231295  23.294491  11.517277   True
# 201321   0.144770  23.283562  11.520297   True
# 201399   0.125816  23.298866  11.517755   True
# ...           ...        ...        ...    ...
# 3293071  0.321304  23.329117  11.540755   True
# 3293217  0.194076  23.274031  11.564058   True
# 3293220  0.134412  23.251869  11.531747   True
# 3293295  0.434706  23.284000  11.552209   True
# 3293301  0.309561  23.353966  11.620544   True
#
# [7904 rows x 4 columns]
#            ENERGY         RA        DEC
# 201051   0.250424  23.293491  11.519407
# 201114   0.165772  23.263769  11.536244
# 201191   0.231295  23.294491  11.517277
# 201321   0.144770  23.283562  11.520297
# 201399   0.125816  23.298866  11.517755
# ...           ...        ...        ...
# 3293071  0.321304  23.329117  11.540755
# 3293217  0.194076  23.274031  11.564058
# 3293220  0.134412  23.251869  11.531747
# 3293295  0.434706  23.284000  11.552209
# 3293301  0.309561  23.353966  11.620544
#
# [7904 rows x 3 columns]

# %%
plt.figure(figsize=(6,5))

plt.scatter(dddfff["RA"], dddfff["DEC"], c=dddfff["ENERGY"], cmap='viridis', s=1)
plt.colorbar()
plt.show()

# %%
rrrr = fits.open('../erosita/erosita_pirmf_v20210719.rmf')
rrrr.info()
ff = rrrr[1].data
len(ff["E_MIN"])
#np.append(ff["E_MIN"], [12.0])
# Out:
# Filename: ../erosita/erosita_pirmf_v20210719.rmf
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  EBOUNDS       1 BinTableHDU     31   1024R x 3C   [I, E, E]
#   2  MATRIX        1 BinTableHDU     42   1024R x 6C   [E, E, I, 1PI(14), 1PI(14), 1PE(924)]
# 1024

# %%
len(np.diff(dummyrsp))
# Out:
# 1024

# %%
N_channels = 1024

#dummyrsp = np.linspace(0.1, 50.0, N_channels+1)
#dummyrsp = np.logspace(np.log10(0.1), np.log10(12.0), N_channels+1)
dummyrsp = np.append(ff["E_MIN"], [12.0])

plt.figure(figsize=(11, 5))

plt.subplot(121)
counts, energies, _ =  plt.hist(dddfff["ENERGY"], bins = dummyrsp)

plt.subplot(122)
plt.plot(energies[1:], counts)
plt.xscale('log')
plt.yscale('log')
plt.axvline(10.0, linestyle = '--', color='black')
plt.xlabel("Energy, keV")
plt.ylabel("Counts")

plt.figure(figsize=(5, 5))

plt.plot(energies[1:], [a/b/10000 for a, b in zip(counts, np.diff(dummyrsp))])
plt.xscale('log')
plt.yscale('log')
plt.axvline(10.0, linestyle = '--', color='black')
plt.xlabel("Energy, keV")
plt.ylabel("Counts / s / keV")

plt.show()

# %%
len(np.diff(energies))
# Out:
# 1024

# %%
datfile = pd.DataFrame({"ENERG_LO":energies[:-1], "ENERG_HI":energies[1:], "COUNTS":counts}) # 
datfile
# Out:
#        ENERG_LO   ENERG_HI  COUNTS
# 0      0.100000   0.104907     1.0
# 1      0.104907   0.109827     2.0
# 2      0.109827   0.114762     1.0
# 3      0.114762   0.119711     6.0
# 4      0.119711   0.124674     9.0
# ...         ...        ...     ...
# 1019  11.881042  11.904634     0.0
# 1020  11.904634  11.928325     0.0
# 1021  11.928325  11.952116     0.0
# 1022  11.952116  11.976006     0.0
# 1023  11.976006  12.000000     0.0
#
# [1024 rows x 3 columns]

# %% [markdown]
# Writing to file:

# %%
datfile.to_csv(f'../data/eROSITA_30.0x30.0/photons/photons_'+str(current_cluster_num)+'.dat', index=True, header=False, sep=' ')

# %% [markdown]
# Reading from file:

# %%
#clusters = pd.read_csv("../data/eROSITA_30.0x30.0/Catalouges/cluster.dat", sep='\s+')

# %% [markdown]
# XSPEC's “native” data format is the OGIP standard. See [XSPEC Data Formats](https://heasarc.gsfc.nasa.gov/xanadu/xspec/manual/node14.html). Useful tool: [ascii2pha](https://heasarc.gsfc.nasa.gov/docs/software/ftools/fhelp/ascii2pha.html) or [ftascii2pha](https://heasarc.gsfc.nasa.gov/lheasoft/help/ftascii2pha.html).
#
# Also see here: [Appendix E: Associated Programs](https://heasarc.gsfc.nasa.gov/xanadu/xspec/manual/node322.html#AppendixPrograms).
#
# [SOXS](https://hea-www.cfa.harvard.edu/soxs/index.html) might be useful. And [HEASoftPY](https://heasarc.gsfc.nasa.gov/docs/software/heasoft/heasoftpy/). Maybe [profit](https://heasarc.gsfc.nasa.gov/docs/software/profit/manual/node16.html)?
#
# Finally, [XSPEC Table Model Generator](https://github.com/mbursa/xspec-table-models/tree/main).

# %% [markdown]
# #### Writing to FITS-file

# %% [markdown]
# Primary header (HDU = Header Data Unit):

# %%
prihdr = fits.Header()

prihdr['COMMENT'] = "FITS (Flexible Image Transport System) format is defined in 'Astronomy  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H"

#display(prihdr)

prihdu = fits.PrimaryHDU(header=prihdr)

display(prihdu.header)
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H

# %% [markdown]
# Table:

# %%
col0 = fits.Column(name='CHANNEL',  format='I', array = np.linspace(1,1024,1024))#datfile["ENERGIES"])
col1 = fits.Column(name='E_MIN', format='E', array = datfile["ENERG_LO"], unit='keV')
col2 = fits.Column(name='E_MAX', format='E', array = datfile["ENERG_HI"], unit='keV')
col3 = fits.Column(name='COUNTS',    format='I', array = datfile["COUNTS"], unit='COUNTS')

cols_spec = fits.ColDefs([col0, col3])
cols_rmf  = fits.ColDefs([col0, col1, col2])

tbhdu_spec = fits.BinTableHDU.from_columns(cols_spec)
tbhdu_rmf  = fits.BinTableHDU.from_columns(cols_rmf)

display(tbhdu_spec.data)
display(tbhdu_rmf.data)
# Out:
# FITS_rec([(   1, 1), (   2, 2), (   3, 1), ..., (1022, 0), (1023, 0),
#           (1024, 0)],
#          dtype=(numpy.record, [('CHANNEL', '<i2'), ('COUNTS', '<i2')]))
# FITS_rec([(   1,  0.1       ,  0.10490672),
#           (   2,  0.10490672,  0.10982741),
#           (   3,  0.10982741,  0.11476217), ...,
#           (1022, 11.928325  , 11.952116  ),
#           (1023, 11.952116  , 11.976006  ),
#           (1024, 11.976006  , 12.        )],
#          dtype=(numpy.record, [('CHANNEL', '<i2'), ('E_MIN', '<f4'), ('E_MAX', '<f4')]))

# %% [markdown]
# Headers for table ([keywords](https://heasarc.gsfc.nasa.gov/docs/heasarc/caldb/docs/memos/cal_gen_92_002/cal_gen_92_002.html)):
#
# Originally [here](https://heasarc.gsfc.nasa.gov/docs/heasarc/ofwg/docs/spectra/ogip_92_007/node6.html).

# %%
thdulist1 = fits.HDUList([prihdu, tbhdu_spec])
hdr1 = thdulist1[1].header

hdr1["EXTNAME"]  = ("SPECTRUM", 'the name (i.e. type) of the extension')
hdr1["TELESCOP"] = ("eROSITA", 'the "telescope" (i.e. mission/satellite name)')
hdr1["INSTRUME"] = ("TM1", 'the instrument/detector')
hdr1["FILTER"]   = ("NONE", 'the instrument filter in use (if any) ')
hdr1["EXPOSURE"] = ("40000", 'the integration time (in seconds) for the PHA data (assumed to be corrected for deadtime, data drop-outs etc. )')
hdr1["BACKFILE"] = ("NONE", 'the name of the corresponding background file (if any)')
hdr1["BACKSCAL"] = ("1", 'the background scaling factor (unless included as a column)')
hdr1["CORRFILE"] = ("NONE", 'the name of the corresponding correction file (if any)')
hdr1["CORRSCAL"] = ("1", 'the correction scaling factor')
hdr1["RESPFILE"] = ("NONE", 'the name of the corresponding (default) redistribution matrix file (RMF; see George et al. 1992a)')
hdr1["ANCRFILE"] = ("NONE", 'the name of the corresponding (default) ancillary response file (ARF; see George et al. 1992a)')
hdr1["AREASCAL"] = ("1", 'the area scaling factor (unless included as a column)')
hdr1["HDUCLASS"] = ("OGIP", 'should contain the string "OGIP" to indicate that this is an OGIP style file')
hdr1["HDUCLAS1"] = ("SPECTRUM", 'should contain the string "SPECTRUM" to indicate this is a spectrum')
hdr1["HDUVERS"]  = ("1.1.0", 'the version number of the format (this document describes version 1.2.1)')
hdr1["POISSERR"] = ("TRUE", 'whether Poissonian errors are appropriate to the data (see below)')
hdr1["CHANTYPE"] = ("PI", 'whether the channels used in the file have been corrected in anyway (see below)')
hdr1["DETCHANS"] = ("1024", 'the total number of detector channels available')

display(hdr1)

thdulist1.writeto('../data/eROSITA_30.0x30.0/photons/pha.fits', overwrite=True)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                    4 / length of dimension 1
# NAXIS2  =                 1024 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    2 / number of table fields
# TTYPE1  = 'CHANNEL '
# TFORM1  = 'I       '
# TTYPE2  = 'COUNTS  '
# TFORM2  = 'I       '
# TUNIT2  = 'COUNTS  '
# EXTNAME = 'SPECTRUM'           / the name (i.e. type) of the extension
# TELESCOP= 'eROSITA '           / the "telescope" (i.e. mission/satellite name)
# INSTRUME= 'TM1     '           / the instrument/detector
# FILTER  = 'NONE    '           / the instrument filter in use (if any)
# EXPOSURE= '40000   '           / the integration time (in seconds) for the PHA d
# BACKFILE= 'NONE    '           / the name of the corresponding background file (
# BACKSCAL= '1       '           / the background scaling factor (unless included
# CORRFILE= 'NONE    '           / the name of the corresponding correction file (
# CORRSCAL= '1       '           / the correction scaling factor
# RESPFILE= 'NONE    '           / the name of the corresponding (default) redistr
# ANCRFILE= 'NONE    '           / the name of the corresponding (default) ancilla
# AREASCAL= '1       '           / the area scaling factor (unless included as a c
# HDUCLASS= 'OGIP    '           / should contain the string "OGIP" to indicate th
# HDUCLAS1= 'SPECTRUM'           / should contain the string "SPECTRUM" to indicat
# HDUVERS = '1.1.0   '           / the version number of the format (this document
# CHANTYPE= 'PI      '           / whether the channels used in the file have been
# DETCHANS= '1024    '           / the total number of detector channels available
# POISSERR= 'TRUE    '           / whether Poissonian errors are appropriate to th

# %%
#rrrr = fits.open('../erosita/erosita_pirmf_v20210719.rmf')
#rrrr.info()

#mmmm = rrrr[2]

# %%
thdulist2 = fits.HDUList([prihdu, tbhdu_rmf, mmmm])
hdr2 = thdulist2[1].header

hdr2["EXTNAME"]  = ("EBOUNDS", 'the name (i.e. type) of the extension')
hdr2["TELESCOP"] = ("eROSITA", 'the "telescope" (i.e. mission/satellite name)')
hdr2["INSTRUME"] = ("TM1", 'the instrument/detector')
hdr2["FILTER"]   = ("NONE", 'the instrument filter in use (if any) ')
hdr2["EXPOSURE"] = ("10000", 'the integration time (in seconds) for the PHA data (assumed to be corrected for deadtime, data drop-outs etc. )')
hdr2["BACKFILE"] = ("NONE", 'the name of the corresponding background file (if any)')
hdr2["BACKSCAL"] = ("1", 'the background scaling factor (unless included as a column)')
hdr2["CORRFILE"] = ("NONE", 'the name of the corresponding correction file (if any)')
hdr2["CORRSCAL"] = ("1", 'the correction scaling factor')
hdr2["RESPFILE"] = ("NONE", 'the name of the corresponding (default) redistribution matrix file (RMF; see George et al. 1992a)')
hdr2["ANCRFILE"] = ("NONE", 'the name of the corresponding (default) ancillary response file (ARF; see George et al. 1992a)')
hdr2["AREASCAL"] = ("1", 'the area scaling factor (unless included as a column)')
hdr2["HDUCLASS"] = ("OGIP", 'should contain the string "OGIP" to indicate that this is an OGIP style file')
hdr2["HDUCLAS1"] = ("RESPONSE", 'should contain the string "SPECTRUM" to indicate this is a spectrum')
hdr2["HDUCLAS2"] = ("EBOUNDS", 'should contain the string "SPECTRUM" to indicate this is a spectrum')
hdr2["HDUVERS"]  = ("1.1.0", 'the version number of the format (this document describes version 1.2.1)')
hdr2["POISSERR"] = ("TRUE", 'whether Poissonian errors are appropriate to the data (see below)')
hdr2["CHANTYPE"] = ("PI", 'whether the channels used in the file have been corrected in anyway (see below)')
hdr2["DETCHANS"] = ("1024", 'the total number of detector channels available')

display(hdr2)

thdulist2.writeto('../data/eROSITA_30.0x30.0/photons/my_rmf.fits', overwrite=True)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   10 / length of dimension 1
# NAXIS2  =                 1024 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    3 / number of table fields
# TTYPE1  = 'CHANNEL '
# TFORM1  = 'I       '
# TTYPE2  = 'E_MIN   '
# TFORM2  = 'E       '
# TUNIT2  = 'keV     '
# TTYPE3  = 'E_MAX   '
# TFORM3  = 'E       '
# TUNIT3  = 'keV     '
# EXTNAME = 'EBOUNDS '           / the name (i.e. type) of the extension
# TELESCOP= 'eROSITA '           / the "telescope" (i.e. mission/satellite name)
# INSTRUME= 'TM1     '           / the instrument/detector
# FILTER  = 'NONE    '           / the instrument filter in use (if any)
# EXPOSURE= '10000   '           / the integration time (in seconds) for the PHA d
# BACKFILE= 'NONE    '           / the name of the corresponding background file (
# BACKSCAL= '1       '           / the background scaling factor (unless included
# CORRFILE= 'NONE    '           / the name of the corresponding correction file (
# CORRSCAL= '1       '           / the correction scaling factor
# RESPFILE= 'NONE    '           / the name of the corresponding (default) redistr
# ANCRFILE= 'NONE    '           / the name of the corresponding (default) ancilla
# AREASCAL= '1       '           / the area scaling factor (unless included as a c
# HDUCLASS= 'OGIP    '           / should contain the string "OGIP" to indicate th
# HDUCLAS1= 'RESPONSE'           / should contain the string "SPECTRUM" to indicat
# HDUCLAS2= 'EBOUNDS '           / should contain the string "SPECTRUM" to indicat
# HDUVERS = '1.1.0   '           / the version number of the format (this document
# POISSERR= 'TRUE    '           / whether Poissonian errors are appropriate to th
# CHANTYPE= 'PI      '           / whether the channels used in the file have been
# DETCHANS= '1024    '           / the total number of detector channels available

# %%
#fits.open('../data/eROSITA_30.0x30.0/photons/table.fits').info()
fits.open('../data/eROSITA_30.0x30.0/photons/pha.fits').info()
# Out:
# Filename: ../data/eROSITA_30.0x30.0/photons/pha.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SPECTRUM      1 BinTableHDU     31   1024R x 2C   [I, I]

# %%
#fits.open('../data/eROSITA_30.0x30.0/photons/my_rmf.fits').info()

# %%
x.AllData.clear()

SPE = '../data/eROSITA_30.0x30.0/photons/pha.fits'

#RMF = '../data/eROSITA_30.0x30.0/photons/my_rmf.fits'

RMF = '../erosita/erosita_pirmf_v20210719.rmf'

ARF = '../erosita/tm1_arf_filter_000101v02.fits'

spectrum = x.Spectrum(SPE, respFile=RMF, arfFile=ARF)
# Out:
# Warning: Statistics not present and Poisson Error Key not set to 'true': setting errors to zero
#
# 1 spectrum  in use
#
# Spectral Data File: ../data/eROSITA_30.0x30.0/photons/pha.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.971e-01 +/- 0.000e+00
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1024
#   Telescope: eROSITA Instrument: TM1  Channel Type: PI
#   Exposure Time: 4e+04 sec
#  Using fit statistic: chi
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                236963.0     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number: 1
#
# Test statistic : Chi-Squared                236963.0     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.0e+00 with 1020 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                59038.35     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number: 1
#
# Test statistic : Chi-Squared                59038.35     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.00e+00 with 1020 degrees of freedom
#  Current data and model not fit yet.
# ***Warning: POISSERR keyword is missing or of wrong format, assuming FALSE.
# Spectrum 1  Spectral Data File: ../data/eROSITA_30.0x30.0/photons/pha.fits
# Net count rate (cts/s) for Spectrum:1  1.971e-01 +/- 0.000e+00
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1024
#   Telescope: eROSITA Instrument: TM1  Channel Type: PI
#   Exposure Time: 4e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File
#  (10.461821556091309, 10.480550765991211),
#  (10.480550765991211, 10.499330520629883),
#  (10.499330520629883, 10.51816463470459),
#  (10.51816463470459, 10.537050247192383),
#  (10.537050247192383, 10.555990219116211),
#  (10.555990219116211, 10.574984550476074),
#  (10.574984550476074, 10.594032287597656),
#  (10.594032287597656, 10.613133430480957),
#  (10.613133430480957, 10.632291793823242),
#  (10.632291793823242, 10.651506423950195),
#  (10.651506423950195, 10.670777320861816),
#  (10.670777320861816, 10.690102577209473),
#  (10.690102577209473, 10.70948600769043),
#  (10.70948600769043, 10.72892951965332),
#  (10.72892951965332, 10.748428344726562),
#  (10.748428344726562, 10.767987251281738),
#  (10.767987251281738, 10.787604331970215),
#  (10.787604331970215, 10.807282447814941),
#  (10.807282447814941, 10.827019691467285),
#  (10.827019691467285, 10.846819877624512),
#  (10.846819877624512, 10.866677284240723),
#  (10.866677284240723, 10.88659954071045),
#  (10.88659954071045, 10.906584739685059),
#  (10.906584739685059, 10.926631927490234),
#  (10.926631927490234, 10.946742057800293),
#  (10.946742057800293, 10.966924667358398),
#  (10.966924667358398, 10.98715877532959),
#  (10.98715877532959, 11.007465362548828),
#  (11.007465362548828, 11.02784252166748),
#  (11.02784252166748, 11.048279762268066),
#  (11.048279762268066, 11.06878662109375),
#  (11.06878662109375, 11.089359283447266),
#  (11.089359283447266, 11.109999656677246),
#  (11.109999656677246, 11.13071060180664),
#  (11.13071060180664, 11.151493072509766),
#  (11.151493072509766, 11.172342300415039),
#  (11.172342300415039, 11.193264961242676),
#  (11.193264961242676, 11.21425724029541),
#  (11.21425724029541, 11.235323905944824),
#  (11.235323905944824, 11.256460189819336),
#  (11.256460189819336, 11.27767276763916),
#  (11.27767276763916, 11.298961639404297),
#  (11.298961639404297, 11.320323944091797),
#  (11.320323944091797, 11.34175968170166),
#  (11.34175968170166, 11.363274574279785),
#  (11.363274574279785, 11.384866714477539),
#  (11.384866714477539, 11.406537055969238),
#  (11.406537055969238, 11.428285598754883),
#  (11.428285598754883, 11.450112342834473),
#  ...)

# %%
spectrum.show()# = np.array(tbhdu_rmf.data)
# Out:
# Spectrum 1  Spectral Data File: ../data/eROSITA_30.0x30.0/photons/pha.fits
# Net count rate (cts/s) for Spectrum:1  1.971e-01 +/- 0.000e+00
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1024
#   Telescope: eROSITA Instrument: TM1  Channel Type: PI
#   Exposure Time: 4e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            ../erosita/erosita_pirmf_v20210719.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ../erosita/tm1_arf_filter_000101v02.fits
#
#  Spectral data counts: 7886
#  Model predicted rate: 0.178012

# %%
x.Plot.device = "/xs"

# %%
x.Plot.xAxis = "keV"

# %%
#x.AllData.ignore("bad")

# %%
x.AllModels.clear()

# %%
x.AllData.notice("all")
# Out:
#   1024 channels (1,1024) noticed in spectrum #     1
#
# All channels noticed

# %%
x.Plot("ldata")

xVals = x.Plot.x()
yVals = x.Plot.y()

plt.figure(figsize=(5, 5))

plt.plot(xVals, yVals)# np.multiply(np.multiply(xVals,xVals),yVals))
plt.xscale('log')
plt.yscale('log')

plt.xlabel(x.Plot.labels()[0])
plt.ylabel(x.Plot.labels()[1])
plt.title(x.Plot.labels()[2])

plt.show()

# %%
x.AllData.ignore("**-0.4 7.0-**")
# Out:
#     57 channels (1-57) ignored in spectrum #     1
#    302 channels (723-1024) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                17492.90     using 665 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number: 1
#
# Test statistic : Chi-Squared                17492.90     using 665 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.00e+00 with 661 degrees of freedom
#  Current data and model not fit yet.

# %%
mod = x.Model('apec')
#mod(2).frozen = False
#mod(3).frozen = False
#mod(6).link = "4"
#mod(6).values = 0

#zzzzz = current_cluster["z_true"]
#mod(3).values = f"{zzzzz}"
# Out:
# Fit statistic  : Chi-Squared                238761.4     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number: 1
#
# Test statistic : Chi-Squared                238761.4     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.0e+00 with 1022 degrees of freedom
#  Current data and model not fit yet.
#
# Parameters have been automatically renormalized.
#
# ========================================================================
# Model apec<1> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.32563E-04  +/-  0.0
# ________________________________________________________________________

# %%
x.AllModels.show()
# Out:
# Parameters defined:
# ========================================================================
# Model apec<1> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.32563E-04  +/-  0.0
# ________________________________________________________________________

# %%
x.Fit.renorm('auto')
#x.Fit.nIterations = 100
#x.Fit.query = 'yes'
#x.Fit.weight = 'standard'
#x.Fit.statMethod = 'chi'

x.Fit.perform()
# Out:
#  Renormalization will be performed automatically
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 238431       3922.4       -3      0.965174   0.000124908
# 237492       1.07441e+06  -4      0.921181   0.000117062
# 236897       3.18708e+06  -5      0.895919   0.000114092
# 235982       2.4739e+06   -6      0.849158   0.000108400
# 235208       2.83319e+06  -7      0.804412   0.000104314
# 234634       2.0743e+06   -8      0.763207   0.000101356
# 234223       1.16751e+06  -9      0.729752   9.93597e-05
# 234027       1.16165e+06 -10      0.715049   9.87161e-05
# 233707       1.26309e+06 -11      0.681714   9.76638e-05
# 233317       541433      -12      0.650405   9.69337e-05
# 232942       1.61598e+06 -13      0.628207   9.69256e-05
# 232075       2.41261e+06 -14      0.585028   9.76565e-05
# 229658       4.3238e+06  -15      0.521458   0.000100453
# 207986       1.31102e+07 -16      0.334325   0.000119491
# 178419       9.46045e+07 -17      0.122488   0.000242025
# 152296       9.30709e+07  -1     0.0842719   0.000717282
# 81069.2      3.77579e+07  -2     0.0923190    0.00150665
# 75981.9      1.19379e+07  -3     0.0896426    0.00144192
# 75845.2      306376       -4     0.0878456    0.00151920
# 75842.7      224805       -5     0.0879352    0.00151930
# 75842.7      15.0447      -6     0.0879352    0.00151930
# ==============================
#  Variances and Principal Axes
#                  1        4
#  1.0309E-11|  0.0508   0.9987
#  1.9240E-08|  0.9987  -0.0508
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.919e-08  -9.754e-10
#   -9.754e-10   5.991e-11
# ------------------------
#
# ========================================================================
# Model apec<1> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      8.79352E-02  +/-  1.38531E-04
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.51930E-03  +/-  7.74027E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                75842.69     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number: 1
#
# Test statistic : Chi-Squared                75842.69     using 1024 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.00e+00 with 1022 degrees of freedom

# %%
x.AllModels.calcFlux('0.1 12.0')
x.AllData(1).flux[0]

#x.Fit.error('1')
# Out:
# 4.101384336738498e-12
# Spectrum 1: Lower range bound          0.1 reset by matrix bound to          0.1
#  Model Flux  0.014719 photons (4.1014e-12 ergs/cm^2/s) range (0.10000 - 12.000 keV)

# %%
#x.AllData.removeDummyrsp()
#x.AllData.dummyrsp(lowE=0.1, highE=50.0, nBins=1024, scaleType='lin')

# %%
x.Plot("ldata")
xVals = x.Plot.x()
yVals = x.Plot.y()
modVals = x.Plot.model()

plt.figure(figsize=(5, 5))

plt.plot(xVals, yVals, xVals, modVals)
plt.xscale('log')
plt.yscale('log')

plt.xlabel(x.Plot.labels()[0])
plt.ylabel(x.Plot.labels()[1])
plt.title(x.Plot.labels()[2])

#plt.ylim(10**(-1), 10**2)

plt.show()

# %%
mod.energies(1) = spectrum.energies
# Out:
#   Input In [858]
#     mod.energies(1) = spectrum.energies
#     ^
# SyntaxError: cannot assign to function call

# %%
sum(mod.folded(1))
# Out:
# 0.7617385107380766

# %% [markdown]
# #### OLD

# %%
halo_number = 187

cluster = clusters.loc[halo_number]

#redshift = cluster["z_true"]

slice_redshift, snap_N = binned_clusters[halo_number]

slice_redshift, snap_N

# %%
plt.figure(figsize=(4,4))

h = 0.704
Omega_M = 0.272

for halo_number in related_clusters:
    
    current_cluster = clusters.loc[halo_number]

    RA_c, DEC_c = current_cluster["x_pix"]*30-5, current_cluster["y_pix"]*30-5
    
    plt.scatter(RA_c, DEC_c, color='red', s=1)
    
    r_500 = current_cluster["R500"]        # kpc/h
    redshift = current_cluster["z_true"]

    D_A = FlatLambdaCDM(H0=100*h, Om0=Omega_M).angular_diameter_distance(redshift) # Mpc

    r_500_rescaled = (r_500/h)/(1000*D_A.value)*180/np.pi  # degrees
    
    plt.gca().add_patch( plt.Circle( (RA_c, DEC_c), r_500_rescaled, fill = False, color='red') )

# %%
hdul = fits.open("/home/aleksei/work/clusters/data/eROSITA_30.0x30.0/Phox/phlist_"+snap_id+".fits")

SLICE = pd.DataFrame(hdul[2].data[:])

ra_ph = SLICE["RA"]
dec_ph = SLICE["DEC"]
ene_ph = SLICE["ENERGY"]

hdul.close()

plt.figure(figsize=(15,14))

plt.scatter(ra_ph, dec_ph, s=1, c=ene_ph, cmap=plt.hot())
#plt.gca().invert_xaxis()
plt.xlabel("R.A., deg")
plt.ylabel("DEC, deg")
#plt.xlim(13,7)
#plt.ylim(7,13)
plt.colorbar(label='Energy, keV')

plt.show()
